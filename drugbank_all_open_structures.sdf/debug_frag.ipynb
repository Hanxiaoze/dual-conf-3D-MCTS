# %%
lib_frag_smi_gt_20 = ['N', 'c1ccccc1', 'O', 'C', 'CC', 'C=O', 'CO', 'CCC', 'CC=O', 'O=CO', 'c1ccncc1', 'CN', 'Clc1ccccc1', 'Oc1ccccc1',\
                    'C1CCNCC1', 'Fc1ccccc1', 'O=P(O)(O)O', 'CNC', 'CCC=O', 'CC(=O)O', 'FC(F)F', 'CC(C)C', 'CCO', 'NC=O', 'C1CCNC1',\
                    'OC1COCC1O', 'C1CNCCN1', 'CCCC', 'C1CC1', 'S', 'C1CCCCC1', 'CCC(=O)O', 'Cc1ccccc1', 'c1cncnc1', 'C1COCCN1', \
                    'OC1COCC(O)C1O', 'CC(C)O', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccc2[nH]ccc2c1', 'CC(N)C(=O)O', 'c1ccsc1', \
                    'c1ccc2ccccc2c1', 'O=[SH](=O)c1ccccc1', 'Nc1ncnc2[nH]cnc12', 'Clc1cccc(Cl)c1', 'O=[N+]([O-])c1ccccc1', 'CCCCC', \
                    'OC1CCOC1', 'C1CCCC1', 'CN1CCNCC1', 'O=P(O)(O)OP(=O)(O)O', 'O=CCO', 'Fc1cccc(F)c1', 'CCCC=O', 'c1cscn1', \
                    'c1ccc2[nH]cnc2c1', 'CCN', 'Oc1ccccc1O', 'NS(=O)(=O)c1ccccc1', 'c1ccc2ncccc2c1', 'Nc1ccccc1', 'O=c1cc[nH]c(=O)[nH]1', \
                    'CS', 'C[SH](=O)=O', 'Brc1ccccc1', 'N#Cc1ccccc1', 'CCCO', 'O=C1CCCN1', 'C=CC', 'Cc1cccc(C)c1', 'CCCC(=O)O', 'c1ccoc1', \
                    'CCCCC(=O)O', 'N=C(N)c1ccccc1', 'CCCCCC', 'c1ncc2nc[nH]c2n1', 'O=C(O)CCCC(=O)O', 'CC(O)CO', 'CN1CCCCC1', 'C[NH+](C)C', \
                    'c1ccc2ncncc2c1', 'N=C(N)N', 'CC(N)C=O', 'O=CNO', 'Nc1cc[nH]c(=O)n1', 'C1CCOC1', 'Cc1c[nH]c(=O)[nH]c1=O', 'CC(F)(F)F', \
                    'NCC=O', 'CC(C)CCC=O', 'Oc1cccc(O)c1', 'Nc1ccc([SH](=O)=O)cc1', 'CC(C)C=O', 'Clc1ccccc1Cl', 'CCCCC=O', 'O=CCCC(=O)O', \
                    'Cn1cccn1', 'c1ccc2c(c1)OCO2', 'CC1(C)CN2C(=O)CC2S1', 'c1ccc2[nH]ncc2c1', 'CC1=C(C(=O)O)N2C(=O)CC2SC1', 'C1CCOCC1', \
                    'c1nc[nH]n1', 'CCC(C)C', 'NS(=O)(=O)O', 'NC(CCC=O)C(=O)O', 'OC1CCOCC1O', 'c1ccc2c(c1)Nc1ccccc1S2', 'CCC(C)O', 'C=CC=O', \
                    'CS(=O)(=O)c1ccccc1', 'c1cnoc1', 'c1nnn[nH]1', 'O=S(=O)(O)O', 'CCCCCCCC', 'CC(=O)[O-]', 'OC(F)(F)F', 'CC(N)=O', \
                    'Cc1ccccn1', 'c1ncc2cc[nH]c2n1', 'c1ncon1', 'Nc1ncccn1', 'c1cnccn1', 'CC(C)C(=O)O', 'Ic1ccccc1', 'CCCCCC=O', 'CC#N', \
                    'Cc1ncccc1O', 'CC(C)N', 'c1ccc2scnc2c1', 'CCCN', 'CCCCCCCCC', 'CCCCCCC', 'CCCCO', 'Fc1ccccc1Cl', 'c1cnc2[nH]ccc2c1', \
                    'c1cc[nH]c1', 'Fc1ccccc1F', 'CC(C)CC=O', 'C1CO1', 'C1CCC1', 'C[NH2+]C', 'OC1CCCCC1', 'O=C1CSC(=O)N1', 'c1ccc2occc2c1', \
                    'C1CN2CCC1CC2', 'CCC(N)C(=O)O', 'Nc1ccccn1', 'CC12CCCCC1CCC2', 'O=CCCO', 'Fc1cccnc1', 'CC(C)(C)C=O', 'C1CNC1', \
                    'CC(=O)NO', 'O=C1CC(=O)NC(=O)N1', 'OC1COC(O)C(O)C1O', 'C#CC', 'Cc1cscn1', 'c1cocn1', 'O=c1cccc[nH]1', 'c1c[nH]nn1', \
                    'Nc1nc2[nH]cnc2c(=O)[nH]1']
print(len(lib_frag_smi_gt_20))
# Out:
# 163

# %%
from rdkit import Chem
from rdkit.Chem import BRICS
import os
from rdkit.Chem import Draw
import copy
from rdkit.Chem import AllChem, DataStructs

lib_smi_iso_frag = ['[3*]O[3*]', '[6*]C(=O)O', '[8*]C[8*]', '[8*]CC[8*]', '[5*]N([5*])[5*]', '[8*]C(F)(F)F', \
'[11*]S[11*]', '[5*]N1CCN([5*])CC1', '[16*]c1c([16*])cc([16*])c([16*])c1', '[5*]N1CCC([15*])CC1', '[8*]C(C)C', \
'[15*]C1CC1', '[15*]C1CCCCC1', '[5*]N1CCOCC1', '[9*]n1cnc2c(N)ncnc21', '[6*]C([6*])=O', '[5*]N1CCC[C@H]1[13*]', \
'[8*]C(C)(C)C', '[14*]c1cccs1', '[15*]C1CCCC1', '[1*]C(N)=O', '[12*]S(=O)(=O)c1ccc([16*])cc1', '[16*]c1c[nH]c2ccccc12', \
'[14*]c1ccnc([14*])n1', '[14*]c1ccc([16*])cn1', '[16*]c1cccc2ccccc12', '[5*]NC(=N)N', '[12*]S(C)(=O)=O', \
'[9*]n1ccc(=O)[nH]c1=O', '[9*]n1ccc(N)nc1=O', '[16*]c1cc([16*])cc([16*])c1', '[9*]n1ccnc1', '[9*]n1cc(C)c(=O)[nH]c1=O', \
'[14*]c1csc([14*])n1', '[14*]c1ccc([14*])o1', '[14*]c1ncnc2cc([16*])c([16*])cc12', '[14*]c1cnc[nH]1', '[14*]c1noc([14*])n1', \
'[9*]n1cnc2c(=O)[nH]c(N)nc21', '[9*]n1nc([14*])cc1[14*]', '[14*]c1cc([14*])ncn1', '[9*]n1cncn1', '[9*]n1cnc2c([14*])ncnc21', \
'[14*]c1cc([14*])[nH]n1', \
    'CCC=O', 'CO', 'C1CCOC1', 'O=P(O)(O)O', 'OC1CCOC1', 'OC1COCC(O)C1O', 'c1ccn2ccnc2c1', 'CC(O)(P(=O)(O)O)P(=O)(O)O', \
        'CC=O', 'CN', 'Clc1ccccc1', 'CCO', 'Fc1ccccc1', 'CNC', 'Oc1ccccc1', 'CC(C)O', 'O=P(O)(O)OP(=O)(O)O']

lib_frag_smi_gt_50 = ['N', 'c1ccccc1', 'O', 'C', 'CC', 'C=O', 'CO', 'CCC', 'CC=O', 'O=CO', 'c1ccncc1', \
                    'CN', 'Clc1ccccc1', 'Oc1ccccc1', 'C1CCNCC1', 'Fc1ccccc1', 'O=P(O)(O)O', 'CNC', 'CCC=O', \
                    'CC(=O)O', 'FC(F)F', 'CC(C)C', 'CCO', 'NC=O', 'C1CCNC1', 'OC1COCC1O', 'C1CNCCN1', 'CCCC', \
                    'C1CC1', 'S', 'C1CCCCC1', 'CCC(=O)O', 'Cc1ccccc1', 'c1cncnc1', 'C1COCCN1', 'OC1COCC(O)C1O',\
                    'CC(C)O', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccc2[nH]ccc2c1', 'CC(N)C(=O)O', 'c1ccsc1',\
                    'c1ccc2ccccc2c1', 'O=[SH](=O)c1ccccc1', 'Nc1ncnc2[nH]cnc12', 'Clc1cccc(Cl)c1', 'O=[N+]([O-])c1ccccc1',\
                    'CCCCC', 'OC1CCOC1', 'C1CCCC1', 'CN1CCNCC1', 'O=P(O)(O)OP(=O)(O)O', 'O=CCO', 'Fc1cccc(F)c1', 'CCCC=O', \
                    'c1cscn1', 'c1ccc2[nH]cnc2c1', 'CCN', 'Oc1ccccc1O', 'NS(=O)(=O)c1ccccc1', 'c1ccc2ncccc2c1', 'Nc1ccccc1', \
                    'O=c1cc[nH]c(=O)[nH]1', 'CS', 'C[SH](=O)=O', 'Brc1ccccc1', 'N#Cc1ccccc1', 'CCCO', 'O=C1CCCN1', 'C=CC', \
                    'Cc1cccc(C)c1', 'CCCC(=O)O', 'c1ccoc1', 'CCCCC(=O)O', 'N=C(N)c1ccccc1', 'CCCCCC', 'c1ncc2nc[nH]c2n1', \
                    'O=C(O)CCCC(=O)O', 'CC(O)CO', 'CN1CCCCC1']

lib_frag_smi_gt_20 = ['N', 'c1ccccc1', 'O', 'C', 'CC', 'C=O', 'CO', 'CCC', 'CC=O', 'O=CO', 'c1ccncc1', 'CN', 'Clc1ccccc1', 'Oc1ccccc1',\
                    'C1CCNCC1', 'Fc1ccccc1', 'O=P(O)(O)O', 'CNC', 'CCC=O', 'CC(=O)O', 'FC(F)F', 'CC(C)C', 'CCO', 'NC=O', 'C1CCNC1',\
                    'OC1COCC1O', 'C1CNCCN1', 'CCCC', 'C1CC1', 'S', 'C1CCCCC1', 'CCC(=O)O', 'Cc1ccccc1', 'c1cncnc1', 'C1COCCN1', \
                    'OC1COCC(O)C1O', 'CC(C)O', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccc2[nH]ccc2c1', 'CC(N)C(=O)O', 'c1ccsc1', \
                    'c1ccc2ccccc2c1', 'O=[SH](=O)c1ccccc1', 'Nc1ncnc2[nH]cnc12', 'Clc1cccc(Cl)c1', 'O=[N+]([O-])c1ccccc1', 'CCCCC', \
                    'OC1CCOC1', 'C1CCCC1', 'CN1CCNCC1', 'O=P(O)(O)OP(=O)(O)O', 'O=CCO', 'Fc1cccc(F)c1', 'CCCC=O', 'c1cscn1', \
                    'c1ccc2[nH]cnc2c1', 'CCN', 'Oc1ccccc1O', 'NS(=O)(=O)c1ccccc1', 'c1ccc2ncccc2c1', 'Nc1ccccc1', 'O=c1cc[nH]c(=O)[nH]1', \
                    'CS', 'C[SH](=O)=O', 'Brc1ccccc1', 'N#Cc1ccccc1', 'CCCO', 'O=C1CCCN1', 'C=CC', 'Cc1cccc(C)c1', 'CCCC(=O)O', 'c1ccoc1', \
                    'CCCCC(=O)O', 'N=C(N)c1ccccc1', 'CCCCCC', 'c1ncc2nc[nH]c2n1', 'O=C(O)CCCC(=O)O', 'CC(O)CO', 'CN1CCCCC1', 'C[NH+](C)C', \
                    'c1ccc2ncncc2c1', 'N=C(N)N', 'CC(N)C=O', 'O=CNO', 'Nc1cc[nH]c(=O)n1', 'C1CCOC1', 'Cc1c[nH]c(=O)[nH]c1=O', 'CC(F)(F)F', \
                    'NCC=O', 'CC(C)CCC=O', 'Oc1cccc(O)c1', 'Nc1ccc([SH](=O)=O)cc1', 'CC(C)C=O', 'Clc1ccccc1Cl', 'CCCCC=O', 'O=CCCC(=O)O', \
                    'Cn1cccn1', 'c1ccc2c(c1)OCO2', 'CC1(C)CN2C(=O)CC2S1', 'c1ccc2[nH]ncc2c1', 'CC1=C(C(=O)O)N2C(=O)CC2SC1', 'C1CCOCC1', \
                    'c1nc[nH]n1', 'CCC(C)C', 'NS(=O)(=O)O', 'NC(CCC=O)C(=O)O', 'OC1CCOCC1O', 'c1ccc2c(c1)Nc1ccccc1S2', 'CCC(C)O', 'C=CC=O', \
                    'CS(=O)(=O)c1ccccc1', 'c1cnoc1', 'c1nnn[nH]1', 'O=S(=O)(O)O', 'CCCCCCCC', 'CC(=O)[O-]', 'OC(F)(F)F', 'CC(N)=O', \
                    'Cc1ccccn1', 'c1ncc2cc[nH]c2n1', 'c1ncon1', 'Nc1ncccn1', 'c1cnccn1', 'CC(C)C(=O)O', 'Ic1ccccc1', 'CCCCCC=O', 'CC#N', \
                    'Cc1ncccc1O', 'CC(C)N', 'c1ccc2scnc2c1', 'CCCN', 'CCCCCCCCC', 'CCCCCCC', 'CCCCO', 'Fc1ccccc1Cl', 'c1cnc2[nH]ccc2c1', \
                    'c1cc[nH]c1', 'Fc1ccccc1F', 'CC(C)CC=O', 'C1CO1', 'C1CCC1', 'C[NH2+]C', 'OC1CCCCC1', 'O=C1CSC(=O)N1', 'c1ccc2occc2c1', \
                    'C1CN2CCC1CC2', 'CCC(N)C(=O)O', 'Nc1ccccn1', 'CC12CCCCC1CCC2', 'O=CCCO', 'Fc1cccnc1', 'CC(C)(C)C=O', 'C1CNC1', \
                    'CC(=O)NO', 'O=C1CC(=O)NC(=O)N1', 'OC1COC(O)C(O)C1O', 'C#CC', 'Cc1cscn1', 'c1cocn1', 'O=c1cccc[nH]1', 'c1c[nH]nn1', \
                    'Nc1nc2[nH]cnc2c(=O)[nH]1']

second_break_rule = {
    'Clc1ccccc1':['c1ccccc1', 'Cl'],
    'Oc1ccccc1':['c1ccccc1', 'O'],
    'Fc1ccccc1':['c1ccccc1', 'F'],
    'CNC':['C', 'N', 'C'],
    'CCC=O':['CC', 'C=O'],
    'CCO':['C', 'CO'],
    'OC1COCC1O':['O', 'O', 'C1COCC1'],
    'CCCC':['CC', 'CC'],
    'CCC(=O)O':['C', 'CC(=O)O'],
    'Cc1ccccc1':['c1ccccc1', 'C'],
    'OC1COCC(O)C1O':['C1CCOCC1','O', 'O', 'O'],
    'CC(C)O':['CO', 'C', 'C'],
    'CC(N)C(=O)O':['CC(=O)O', 'C', 'N'],
    'O=[SH](=O)c1ccccc1':['c1ccccc1', 'S(=O)=O'],
    'Clc1cccc(Cl)c1':['Cl', 'Cl', 'c1ccccc1'],
    'CCCCC':['CC', 'CC', 'C'],
    'OC1CCOC1':['C1COCC1', 'O'],
    'CN1CCNCC1':['C1CNCCN1', 'C'],
    'O=CCO':['C=O', 'CO'],
    'Fc1cccc(F)c1':['c1ccccc1', 'F', 'F'],
    'CCCC=O':['C=O', 'CC', 'C'],
    'CCN':['CC', 'N'],
    'Oc1ccccc1O':['c1ccccc1', 'O', 'O'],
    'NS(=O)(=O)c1ccccc1':['c1ccccc1', 'S(=O)=O', 'N'],
    'Nc1ccccc1':['c1ccccc1', 'N'],
    'CS':['C', 'S'],
    'C[SH](=O)=O':['C', 'S(=O)=O'],
    'Brc1ccccc1':['c1ccccc1', 'Br'],
    'N#Cc1ccccc1':['c1ccccc1', 'C#N'],
    'CCCO':['CC', 'CO'],
    'Cc1cccc(C)c1':['c1ccccc1', 'C', 'C'],
    'CCCC(=O)O':['CC(=O)O', 'CC'],
    'CCCCC(=O)O':['CC(=O)O', 'CC', 'C'],
    'CCCCCC':['CC', 'CC', 'CC'],
    'O=C(O)CCCC(=O)O':['CC(=O)O','CC(=O)O', 'C'],
    'CC(O)CO':['CO', 'CO', 'C'],
    'CN1CCCCC1':['C1CCNCC1', 'C'],
    'CC(N)C=O':['C=O', 'CC', 'N'],
    'O=CNO':['CO', 'N', 'O'],
    'CC(F)(F)F':['C(F)(F)F', 'C'],
    'NCC=O':['C=O', 'C', 'N'],
    'CC(C)CCC=O':['C=O', 'CC', 'CC', 'C'],
    'Oc1cccc(O)c1':['c1ccccc1', 'O', 'O'],
    'Nc1ccc([SH](=O)=O)cc1':['S(=O)=O', 'c1ccccc1', 'N'],
    'CC(C)C=O':['C=O', 'CC', 'C'],
    'Clc1ccccc1Cl':['c1ccccc1', 'Cl', 'Cl'],
    'CCCCC=O':['C=O', 'CC', 'CC'],
    'O=CCCC(=O)O':['CC(=O)O', 'CC=O'],
    'Cn1cccn1':['c1cn[nH]c1', 'C'],
    'CCC(C)C':['CC', 'CC', 'C'],
    'NS(=O)(=O)O':['S(=O)=O', 'N', 'O'],
    'NC(CCC=O)C(=O)O':['CC=O', 'CC', 'N', 'O=CO'],
    'OC1CCOCC1O':['C1CCOCC1', 'O', 'O'],
    'CCC(C)O':['CC', 'CC', 'O'],
    'CS(=O)(=O)c1ccccc1':['c1ccccc1', 'S(=O)=O', 'C'],
    'O=S(=O)(O)O':['S(=O)=O', 'O', 'O'],
    'CCCCCCCC':['CC', 'CC', 'CC', 'CC'],
    'CC(=O)[O-]':['CC(=O)O'],
    'OC(F)(F)F':['C(F)(F)F', 'O'],
    'CC(N)=O':['CC=O', 'N'],
    'Cc1ccccn1':['c1ccncc1', 'C'],
    'Nc1ncccn1':['c1cncnc1', 'N'],
    'CC(C)C(=O)O':['O=CO', 'CC', 'C'],
    'Ic1ccccc1':['c1ccccc1', 'I'],
    'CCCCCC=O':['CC=O', 'CC', 'CC'],
    'CC#N':['C#N', 'C'],
    'Cc1ncccc1O':['c1ccncc1', 'O', 'C'],
    'CC(C)N':['CC', 'C', 'N'],
    'CCCN':['CCC', 'N'],
    'CCCCCCCCC':['CCC', 'CCC', 'CCC'],
    'CCCCCCC':['CCC', 'CCC', 'C'],
    'CCCCO':['CCC', 'CO'],
    'Fc1ccccc1Cl':['c1ccccc1', 'F', 'Cl'],
    'Fc1ccccc1F':['c1ccccc1', 'F', 'F'],
    'CC(C)CC=O':['C=O', 'CCC', 'C'],
    'C[NH2+]C':['C', 'N', 'C'],
    'OC1CCCCC1':['C1CCCCC1', 'O'],
    'CCC(N)C(=O)O':['CC', 'CN', 'C(=O)O'],
    'Nc1ccccn1':['c1ccncc1', 'N'],
    'O=CCCO':['CC=O', 'CO'],
    'Fc1cccnc1':['c1ccncc1', 'F'],
    'CC(C)(C)C=O':['CC(C)C', 'C=O'],
    'CC(=O)NO':['CC=O', 'N', 'O'],
    'OC1COC(O)C(O)C1O':['C1CCOCC1','O', 'O', 'O', 'O'],
    'Cc1cscn1':['c1cscn1', 'C'],

}


def second_break_funcbb(to_break_smi):
    to_break_mol = Chem.MolFromSmiles(to_break_smi)
    res = []
    try:
        for k, v in second_break_rule.items():
            # print(k, v)
            lib_mol = Chem.MolFromSmiles(str(k))
            if Chem.RemoveHs(to_break_mol).HasSubstructMatch(Chem.RemoveHs(lib_mol)) and \
                        Chem.RemoveHs(lib_mol).HasSubstructMatch(Chem.RemoveHs(to_break_mol)):
                res = v
                break
            else:
                res = [to_break_smi]                
    except Exception as e:
        print(f'Error in {to_break_smi}: {e}')
    return res


def second_break_funcbbb(to_break_smi):
    to_break_mol = Chem.MolFromSmiles(to_break_smi)
    res = []
    try:
        for k, v in second_break_rule.items():
            # 获取库中的分子结构
            lib_mol = Chem.MolFromSmiles(str(k))
            
            # 转化为SMILES并去除空格和换行符
            to_break_smi_canonical = Chem.MolToSmiles(to_break_mol, canonical=True).strip()
            lib_smi_canonical = Chem.MolToSmiles(lib_mol, canonical=True).strip()
            
            # print(to_break_smi_canonical, '    ', lib_smi_canonical)
            
            # 比较标准化后的SMILES
            if to_break_smi_canonical == lib_smi_canonical:
                # print('yes')
                res = v
                break
            else:
                res = [to_break_smi]
                # print('not match!!!')
    except Exception as e:
        print(f'Error in {to_break_smi}: {e}')
    return res

def second_break_func(to_break_smi):
    to_break_mol = Chem.MolFromSmiles(to_break_smi)
    res = []
    rdkit_gen = Chem.rdFingerprintGenerator.GetRDKitFPGenerator(maxPath=5)
    try:
        for k, v in second_break_rule.items():
            lib_mol = Chem.MolFromSmiles(str(k))
            
            # 生成分子指纹
            fp1 = rdkit_gen.GetFingerprint(to_break_mol)
            fp2 = rdkit_gen.GetFingerprint(lib_mol)
            
            # 比较指纹相似性，1.0 表示完全相同
            if DataStructs.FingerprintSimilarity(fp1, fp2) == 1.0:                
                res = v
                break  # 找到匹配后跳出循环
            else:
                res = [to_break_smi]                
    except Exception as e:
        print(f'Error in {to_break_smi}: {e}')
    return res

lib_frag_smi_gt_20_secon_break = []

for smi in lib_frag_smi_gt_20:
    smi_li = second_break_funcbb(smi)
    print(smi_li)
    for i in smi_li:
        if i not in lib_frag_smi_gt_20_secon_break:
            lib_frag_smi_gt_20_secon_break.append(i)

lib_frag_mol_gt_20_secon_break = [ Chem.MolFromSmiles(i) for i in lib_frag_smi_gt_20_secon_break]

print(lib_frag_smi_gt_20_secon_break)
print(len(lib_frag_smi_gt_20_secon_break))

Draw.MolsToGridImage(lib_frag_mol_gt_20_secon_break, legends=lib_frag_smi_gt_20_secon_break, molsPerRow=6, maxMols=200, subImgSize=(300, 300))
# Out:
# ['N']
# ['c1ccccc1']
# ['O']
# ['C']
# ['CC']
# ['C=O']
# ['CO']
# ['CCC']
# ['CC=O']
# ['O=CO']
# ['c1ccncc1']
# ['CN']
# ['c1ccccc1', 'Cl']
# ['c1ccccc1', 'O']
# ['C1CCNCC1']
# ['c1ccccc1', 'F']
# ['O=P(O)(O)O']
# ['C', 'N', 'C']
# ['CC', 'C=O']
# ['CC(=O)O']
# ['FC(F)F']
# ['CC(C)C']
# ['C', 'CO']
# ['NC=O']
# ['C1CCNC1']
# ['O', 'O', 'C1COCC1']
# ['C1CNCCN1']
# ['CC', 'CC']
# ['C1CC1']
# ['S']
# ['C1CCCCC1']
# ['C', 'CC(=O)O']
# ['c1ccccc1', 'C']
# ['c1cncnc1']
# ['C1COCCN1']
# ['C1CCOCC1', 'O', 'O', 'O']
# ['CO', 'C', 'C']
# ['c1cn[nH]c1']
# ['c1c[nH]cn1']
# ['c1ccc2[nH]ccc2c1']
# ['CC(=O)O', 'C', 'N']
# ['c1ccsc1']
# ['c1ccc2ccccc2c1']
# ['c1ccccc1', 'S(=O)=O']
# ['Nc1ncnc2[nH]cnc12']
# ['Cl', 'Cl', 'c1ccccc1']
# ['O=[N+]([O-])c1ccccc1']
# ['CC', 'CC', 'C']
# ['C1COCC1', 'O']
# ['C1CCCC1']
# ['C1CNCCN1', 'C']
# ['O=P(O)(O)OP(=O)(O)O']
# ['C=O', 'CO']
# ['c1ccccc1', 'F', 'F']
# ['C=O', 'CC', 'C']
# ['c1cscn1']
# ['c1ccc2[nH]cnc2c1']
# ['CC', 'N']
# ['c1ccccc1', 'O', 'O']
# ...

# %%
lib_smi_iso_frag = lib_frag_smi_gt_20

lib_mol_iso_frag = [Chem.MolFromSmiles(frag) for frag in lib_smi_iso_frag]

def mol_iso_2_mol_H(mol_iso, isotope=list(range(1, 50))):
    for atom in mol_iso.GetAtoms():
        # 检查是否有同位素标记
        if atom.GetIsotope() in isotope:
            # 获取当前原子的索引
            idx = atom.GetIdx()
            # 使用氢原子替换该原子
            mol_iso.GetAtomWithIdx(idx).SetAtomicNum(1)  # 将原子的原子序数设置为 1，即氢
            mol_iso.GetAtomWithIdx(idx).SetIsotope(0)   # 移除同位素标记
            mol_iso = Chem.AddHs(mol_iso)     
    return mol_iso

unique_lib_mol_H_frag = [mol_iso_2_mol_H(frag) for frag in lib_mol_iso_frag]

lib_smi_H_frag = [Chem.MolToSmiles(frag) for frag in unique_lib_mol_H_frag]
lib_mol_H_frag = [Chem.MolFromSmiles(frag) for frag in lib_smi_H_frag]

print(lib_smi_iso_frag)
print(lib_smi_H_frag)
print(len(lib_smi_H_frag))

Draw.MolsToGridImage(unique_lib_mol_H_frag, legends=lib_smi_H_frag, molsPerRow=8, subImgSize=(300, 300))

# 去除重复元素
unique_lib_smi_H_frag = list(set(lib_smi_H_frag))
unique_lib_mol_H_frag = [ Chem.MolFromSmiles(frag) for frag in unique_lib_smi_H_frag]

print(len(unique_lib_mol_H_frag))

# Draw.MolsToGridImage(unique_lib_mol_H_frag[0:60], legends=unique_lib_smi_H_frag[0:60], molsPerRow=6, maxMols=200, subImgSize=(300, 300))

Draw.MolsToGridImage(lib_mol_H_frag[120:], legends=lib_smi_H_frag[120:], molsPerRow=6, maxMols=200, subImgSize=(300, 300))

# %%
# 函数：对分子进行 BRICS 切片并与 target_fragments_1 进行比对
def decompose_and_match(drug_sdf, unique_lib_mol_H_frag):
    # 将 SMILES 转换为 RDKit 分子对象
    supplier = Chem.SDMolSupplier(drug_sdf)
    for mol in supplier:
        if mol is None:
            print(f"Invalid SDF: {drug_sdf}")
            return []

        # 使用 BRICS 进行分子切片
        break_out_smi = list(BRICS.BRICSDecompose(mol))
        
        # 将切片后的片段转换为 RDKit 分子对象
        break_out_mols = [Chem.MolFromSmiles(frag) for frag in break_out_smi]

        # 存储片段所属的列表 ID
        fragment_ids = []

        # 遍历切片后的每个片段分子对象
        for break_out_mol in break_out_mols:
            break_out_mol = mol_iso_2_mol_H(break_out_mol)   # 去除 drug 碎片中同位素
            # 默认设置为 'xxx'
            frag_id = 'xxx'
            
            # 如果 fragment_mol 无效，继续下一个片段
            if break_out_mol is None:
                fragment_ids.append(frag_id)
                continue

            # 遍历 target_fragments_1 中的每个列表
            for idx, lib_frag in enumerate(unique_lib_mol_H_frag):
                # 检查片段是否在当前列表的任一 SMARTS 中匹配            
                if Chem.RemoveHs(lib_frag).HasSubstructMatch(Chem.RemoveHs(break_out_mol)) and \
                    Chem.RemoveHs(break_out_mol).HasSubstructMatch(Chem.RemoveHs(lib_frag)):
                    frag_id = str(idx + 1)  # 将列表索引作为 ID
                    break
                
            # 将片段所属的 ID 添加到结果中
            fragment_ids.append(frag_id)

    return fragment_ids


# 指定.smi文件所在的文件夹路径
folder_path = './mol_sdf_3D_600'
sdf_files = [f for f in os.listdir(folder_path) if f.endswith('.sdf')]

# 用于存储数据的列表
data = []

i = 0
# 遍历每个 drug 的 .sdf 文件
with open("success_break_result.txt", "w") as file:
    for sdf_file in sdf_files:
        i += 1
        file_path = os.path.join(folder_path, sdf_file)
        try:
            result = decompose_and_match(file_path, unique_lib_mol_H_frag)       
            print(f"【{i}】【{sdf_file}】Fragments IDs for {sdf_file}: {result}")   
            if 'xxx' not in result:
                file.writelines(f"{sdf_file}: {result}\n")
        except Exception as e:
            # 捕获并打印错误详细信息
            print(f"Error in {file_path}: {e}")
# Out:
# 【1】【drugbank_mol_6728.sdf】Fragments IDs for drugbank_mol_6728.sdf: ['79', '29', '107', '33', '100', '92', '140']
# 【2】【drugbank_mol_8843.sdf】Fragments IDs for drugbank_mol_8843.sdf: ['83', '18', '27']
# 【3】【drugbank_mol_3285.sdf】Fragments IDs for drugbank_mol_3285.sdf: ['97', '69', '15', '106', '13', '47', '52']
# 【4】【drugbank_mol_10467.sdf】Fragments IDs for drugbank_mol_10467.sdf: ['108', 'xxx', '148']
# 【5】【drugbank_mol_1790.sdf】Fragments IDs for drugbank_mol_1790.sdf: ['33', '100', '6', '144']
# 【6】【drugbank_mol_10026.sdf】Fragments IDs for drugbank_mol_10026.sdf: ['xxx']
# 【7】【drugbank_mol_9284.sdf】Fragments IDs for drugbank_mol_9284.sdf: ['xxx']
# 【8】【drugbank_mol_6971.sdf】Fragments IDs for drugbank_mol_6971.sdf: ['16', 'xxx', 'xxx']
# 【9】【drugbank_mol_11106.sdf】Fragments IDs for drugbank_mol_11106.sdf: ['107', '142', '33', 'xxx', '47', '100', '87']
# 【10】【drugbank_mol_1903.sdf】Fragments IDs for drugbank_mol_1903.sdf: ['113', 'xxx', '140', '62', '100', '83', '125', '50']
# ...

# %%
i = 0
decomp_ob_li = []
decomp_lab_li = []
# 遍历每个.smi文件
for sdf_file in sdf_files:
    i += 1
    file_path = os.path.join(folder_path, sdf_file)
    supplier = Chem.SDMolSupplier(file_path)
    for mol in supplier:   
        smi = Chem.MolToSmiles(mol) 
        decomp_lab_li.append(smi)    # 先加上 drug 的 smiles
        decomp_lab_li += list(BRICS.BRICSDecompose(mol))
        # decomp_lab_li += list(BRICS.BreakBRICSBonds(mol))
        # decomp_lab_li += list(BRICS.BRICSBuild(mol))
        decomp_lab_li.append(smi)
        decomp_lab_li += [ Chem.MolToSmiles(mol_iso_2_mol_H(Chem.MolFromSmiles(i))) for i in list(BRICS.BRICSDecompose(mol))]
    
# 将切片后的片段转换为 RDKit 分子对象
decomp_ob_li = [Chem.MolFromSmiles(frag) for frag in decomp_lab_li]

copied_list = copy.deepcopy(decomp_ob_li)
# 去除手性信息并获取 SMILES, Chem.RemoveStereochemistry() 是就地操作函数，不返回对象
for frag in copied_list:
    Chem.RemoveStereochemistry(frag)

decomp_lab_li = [Chem.MolToSmiles(frag, canonical=True, allHsExplicit=False) for frag in copied_list]
print(decomp_lab_li)
Draw.MolsToGridImage(decomp_ob_li, legends=decomp_lab_li, molsPerRow=6, subImgSize=(300, 300))
# Out:
# [14:26:00] WARNING: not removing hydrogen atom without neighbors
# [14:26:00] WARNING: not removing hydrogen atom without neighbors
# [14:26:00] WARNING: not removing hydrogen atom without neighbors
# [14:26:00] WARNING: not removing hydrogen atom without neighbors
# [14:26:46] ERROR: Cannot process coordinates on line 15
# [14:26:46] ERROR: moving to the beginning of the next molecule
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Input In [132], in <cell line: 5>()
#       8 supplier = Chem.SDMolSupplier(file_path)
#       9 for mol in supplier:
# ---> 10     smi = Chem.MolToSmiles(mol)
#      11     decomp_lab_li.append(smi)    # 先加上 drug 的 smiles
#      12     decomp_lab_li += list(BRICS.BRICSDecompose(mol))
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmiles(NoneType)
# did not match C++ signature:
# ...

# %% [markdown]
# ## 统计 DrugBank 中 drug 分子的出现频率

# %%
unique_lib_smi_H_frag_impliH = [ Chem.MolToSmiles(Chem.MolFromSmiles(i)) for i in unique_lib_smi_H_frag]
print(unique_lib_smi_H_frag_impliH)
# Draw.MolsToGridImage(unique_lib_mol_H_frag, legends=unique_lib_smi_H_frag, molsPerRow=8, subImgSize=(300, 300))


def count_fragments_in_sdf(folder_path, all=True):
    # 初始化空字典用于记录片段频率
    fragment_dict = {}    
    # 获取文件夹中的所有 SDF 文件
    sdf_files = [f for f in os.listdir(folder_path) if f.endswith('.sdf')]
    
    # 遍历每个 SDF 文件
    for sdf_file in sdf_files:
        # 读取每个 SDF 文件中的分子
        file_path = os.path.join(folder_path, sdf_file)
        suppl = Chem.SDMolSupplier(file_path)
        
        for mol in suppl:
            if mol is None:  # 忽略读取错误的分子
                continue
            
            # 使用 BRICS 分解分子
            drug_break_smis = list(BRICS.BRICSDecompose(mol))
            drug_break_mols = [Chem.MolFromSmiles(frag) for frag in drug_break_smis]            
            
            for drug_break_mol in drug_break_mols:
                try:
                    # 根据需求对分子进行处理
                    drug_break_mol = mol_iso_2_mol_H(drug_break_mol)    
                    Chem.RemoveStereochemistry(drug_break_mol)
                    drug_break_mol = Chem.RemoveHs(drug_break_mol)
                    drug_break_smi = Chem.MolToSmiles(drug_break_mol)
                    # drug_break_smi = Chem.MolToSmiles(Chem.MolFromSmiles(Chem.MolToSmiles(drug_break_mol)))
                    
                    # 统计片段出现次数，使用字典记录
                    if all:
                        if drug_break_smi in fragment_dict:
                            fragment_dict[drug_break_smi] += 1
                        else:
                            fragment_dict[drug_break_smi] = 1
                    else:
                        if drug_break_smi not in unique_lib_smi_H_frag_impliH:
                            if drug_break_smi in fragment_dict:
                                fragment_dict[drug_break_smi] += 1
                            else:
                                fragment_dict[drug_break_smi] = 1
                except Exception as e:
                    print(f'Errors in {sdf_file}: {e}')
                    

    sorted_frag_dict = dict(sorted(fragment_dict.items(), key=lambda item: item[1], reverse=True))
    return sorted_frag_dict

fragment_dict_all = count_fragments_in_sdf('./mol_sdf_3D_600', all=True)
fragment_dict_extra = count_fragments_in_sdf('./mol_sdf_3D_600', all=False)
print(fragment_dict_all)
print(fragment_dict_extra)
# Out:
# ['c1ccncc1', 'N', 'Nc1ncnc2[nH]cnc12', 'C1CCNC1', 'C1CNCCN1', 'CO', 'c1ccc2[nH]ccc2c1', 'Cc1c[nH]c(=O)[nH]c1=O', 'C', 'c1ccccc1', 'c1ccc2ncncc2c1', 'Nc1nc2[nH]cnc2c(=O)[nH]1', 'Oc1ccccc1', 'C1CCOC1', 'C=O', 'CCO', 'O=P(O)(O)O', 'c1ccoc1', 'c1nc[nH]n1', 'CN', 'O=c1cc[nH]c(=O)[nH]1', 'OC1CCOC1', 'C1CC1', 'CC', 'c1c[nH]cn1', 'CCC=O', 'CC(O)(P(=O)(O)O)P(=O)(O)O', 'NC=O', 'Fc1ccccc1', 'C1CCNCC1', 'c1cn[nH]c1', 'c1ccsc1', 'OC1COCC(O)C1O', 'S', 'c1ccn2ccnc2c1', 'O', 'CNC', 'C1CCCCC1', 'C1CCCC1', 'CC(C)O', 'O=CO', 'C[SH](=O)=O', 'CC=O', 'Clc1ccccc1', 'O=P(O)(O)OP(=O)(O)O', 'O=[SH](=O)c1ccccc1', 'Nc1cc[nH]c(=O)n1', 'N=C(N)N', 'c1cscn1', 'c1ccc2ccccc2c1', 'c1ncon1', 'FC(F)F', 'C1COCCN1', 'c1ncc2nc[nH]c2n1', 'c1cncnc1', 'CC(C)C', 'CCC']
# [14:45:38] WARNING: not removing hydrogen atom without neighbors
# [14:45:38] WARNING: not removing hydrogen atom without neighbors
# [14:45:38] WARNING: not removing hydrogen atom without neighbors
# ...

# %%
lib_frag_smi_gt_20 = []
for k, v in fragment_dict_all.items():
    # print(f'{k}:   {v}')
    if v >= 20:
        lib_frag_smi_gt_20.append(k)
print(lib_frag_smi_gt_20)
# Out:
# ['N', 'c1ccccc1', 'O', 'C', 'CC', 'C=O', 'CO', 'CCC', 'CC=O', 'O=CO', 'c1ccncc1', 'CN', 'Clc1ccccc1', 'Oc1ccccc1', 'C1CCNCC1', 'Fc1ccccc1', 'O=P(O)(O)O', 'CNC', 'CCC=O', 'CC(=O)O', 'FC(F)F', 'CC(C)C', 'CCO', 'NC=O', 'C1CCNC1', 'OC1COCC1O', 'C1CNCCN1', 'CCCC', 'C1CC1', 'S', 'C1CCCCC1', 'CCC(=O)O', 'Cc1ccccc1', 'c1cncnc1', 'C1COCCN1', 'OC1COCC(O)C1O', 'CC(C)O', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccc2[nH]ccc2c1', 'CC(N)C(=O)O', 'c1ccsc1', 'c1ccc2ccccc2c1', 'O=[SH](=O)c1ccccc1', 'Nc1ncnc2[nH]cnc12', 'Clc1cccc(Cl)c1', 'O=[N+]([O-])c1ccccc1', 'CCCCC', 'OC1CCOC1', 'C1CCCC1', 'CN1CCNCC1', 'O=P(O)(O)OP(=O)(O)O', 'O=CCO', 'Fc1cccc(F)c1', 'CCCC=O', 'c1cscn1', 'c1ccc2[nH]cnc2c1', 'CCN', 'Oc1ccccc1O', 'NS(=O)(=O)c1ccccc1', 'c1ccc2ncccc2c1', 'Nc1ccccc1', 'O=c1cc[nH]c(=O)[nH]1', 'CS', 'C[SH](=O)=O', 'Brc1ccccc1', 'N#Cc1ccccc1', 'CCCO', 'O=C1CCCN1', 'C=CC', 'Cc1cccc(C)c1', 'CCCC(=O)O', 'c1ccoc1', 'CCCCC(=O)O', 'N=C(N)c1ccccc1', 'CCCCCC', 'c1ncc2nc[nH]c2n1', 'O=C(O)CCCC(=O)O', 'CC(O)CO', 'CN1CCCCC1', 'C[
# ...

# %%
# 函数：对分子进行 BRICS 切片并与 target_fragments_1 进行比对
def decompose_and_match(smiles, converted_fragments):
    # 将 SMILES 转换为 RDKit 分子对象
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        print(f"Invalid SMILES: {smiles}")
        return []

    # 使用 BRICS 进行分子切片
    fragments = list(BRICS.BRICSDecompose(mol))
    
    # 将切片后的片段转换为 RDKit 分子对象
    fragment_mols = [Chem.MolFromSmiles(frag) for frag in fragments]

    # 存储片段所属的列表 ID
    fragment_ids = []

    # 遍历切片后的每个片段分子对象
    for fragment_mol in fragment_mols:
        # 默认设置为 'xxx'
        fragment_id = 'xxx'
        
        # 如果 fragment_mol 无效，继续下一个片段
        if fragment_mol is None:
            fragment_ids.append(fragment_id)
            continue

        # 遍历 target_fragments_1 中的每个列表
        for idx, frag_list in enumerate(converted_fragments):
            # 检查片段是否在当前列表的任一 SMARTS 中匹配
            for target_mol in frag_list:
                # if target_mol.HasSubstructMatch(fragment_mol) and fragment_mol.HasSubstructMatch(target_mol):
                if Chem.RemoveHs(target_mol).HasSubstructMatch(Chem.RemoveHs(fragment_mol)):
                    fragment_id = str(idx)  # 将列表索引作为 ID
                    break

            # 如果找到了匹配的列表，则退出循环
            if fragment_id != 'xxx':
                break

        # 将片段所属的 ID 添加到结果中
        fragment_ids.append(fragment_id)

    return fragment_ids


# 指定.smi文件所在的文件夹路径
folder_path = './record_5000_smi'
sdf_files = [f for f in os.listdir(folder_path) if f.endswith('999.smi')]

# 用于存储数据的列表
data = []

i = 0
# 遍历每个.smi文件
for sdf_file in sdf_files:
    i += 1
    file_path = os.path.join(folder_path, sdf_file)
    with open(file_path, 'r') as file:
        # 读取文件内容，假设每行是一个SMILES
        for line in file:
            smi = str(line.strip().split()[0])  
    result = decompose_and_match(smi, converted_fragments)   
    print(f"【{i}】【{sdf_file}】Fragments IDs for {smi}: {result}")

# %%
from rdkit.Chem import Draw

mol_ob_li = []
mol_lab_li = []
for smi_li in target_fragments_1:
    for smi in smi_li:
        mol_ob_li.append(Chem.MolFromSmiles(smi))

for smi_li in target_fragments_1:
    for smi in smi_li:
        mol_lab_li.append(smi)

img = Draw.MolsToGridImage(mol_ob_li, legends=mol_lab_li, molsPerRow=8, subImgSize=(300, 300))
img
# Out:
# /home/zhou/anaconda3/envs/admet_ai/lib/python3.10/site-packages/rdkit/Chem/Draw/IPythonConsole.py:261: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   warnings.warn(

# %%
i = 0
# 遍历每个.smi文件
for sdf_file in sdf_files:
    i += 1
    file_path = os.path.join(folder_path, sdf_file)
    with open(file_path, 'r') as file:
        # 读取文件内容，假设每行是一个SMILES
        for line in file:
            smi = str(line.strip().split()[0])  
    result = decompose_and_match(smi, converted_fragments)   
    print(f"【{i}】【{sdf_file}】Fragments IDs for {smi}: {result}")

i = 0
decomp_ob_li = []
decomp_lab_li = []
# 遍历每个.smi文件
for sdf_file in sdf_files:
    i += 1
    file_path = os.path.join(folder_path, sdf_file)
    with open(file_path, 'r') as file:
        # 读取文件内容，假设每行是一个SMILES
        for line in file:
            smi = str(line.strip().split()[0])
            decomp_lab_li.append(smi)
            mol = Chem.MolFromSmiles(smi)

            decomp_lab_li += list(BRICS.BRICSDecompose(mol))
    
# 将切片后的片段转换为 RDKit 分子对象
decomp_ob_li = [Chem.MolFromSmiles(frag) for frag in decomp_lab_li]

img2 = Draw.MolsToGridImage(decomp_ob_li, legends=decomp_lab_li, molsPerRow=8, subImgSize=(300, 300))
img2
# Out:
# 【1】【record_999.smi】Fragments IDs for n1(cnc2CN=C(Nc12)n1cnc2c(=O)[nH]c(N)nc12)Cn1ccc(n1)Cc1ccncn1: ['23', '39', 'xxx', '2']
# 【2】【record_1999.smi】Fragments IDs for [C@H]1(CCC[C@@H](C1)c1noc(n1)n1ccc(=O)[nH]c1=O)c1ncccn1: ['xxx', '23', '37', '28']
# 【3】【record_4999.smi】Fragments IDs for c1(noc(n1)n1cnc2CN=C(Nc12)n1cnc2cncnc12)Sc1cc(ncn1)c1cccs1: ['6', '40', '18', 'xxx', '37']
# 【4】【record_3999.smi】Fragments IDs for c1(c[nH]c2cc(ccc12)n1cnc2CN=CNc12)c1ccnc(n1)C(F)(F)F: ['xxx', '23', 'xxx', '5']
# 【5】【record_2999.smi】Fragments IDs for C1(=CCN=C(N1)c1ccnc(n1)n1cnc2c(ncnc12)N)c1c[nH]c2ccccc12: ['14', 'xxx']
